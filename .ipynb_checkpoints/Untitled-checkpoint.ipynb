# %%
norm = np.random.normal(0, 1, 100)

plt.hist(norm)
# Out:
# (array([ 9.,  8., 13., 19., 14., 13., 13.,  9.,  1.,  1.]),
#  array([-2.11352851, -1.6450072 , -1.17648588, -0.70796456, -0.23944324,
#          0.22907807,  0.69759939,  1.16612071,  1.63464203,  2.10316335,
#          2.57168466]),
#  <a list of 10 Patch objects>)
